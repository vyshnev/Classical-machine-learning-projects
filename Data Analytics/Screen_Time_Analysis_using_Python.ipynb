# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r'C:\Users\vyshn\Downloads\Screentime-App-Details.csv')

# %%
print(data.head())
# Out:
#          Date  Usage  Notifications  Times opened        App
# 0  08/26/2022     38             70            49  Instagram
# 1  08/27/2022     39             43            48  Instagram
# 2  08/28/2022     64            231            55  Instagram
# 3  08/29/2022     14             35            23  Instagram
# 4  08/30/2022      3             19             5  Instagram

# %%
data.isna().sum()
# Out:
# Date             0
# Usage            0
# Notifications    0
# Times opened     0
# App              0
# dtype: int64

# %%
print(data.describe().T)
# Out:
#                count        mean        std  min    25%   50%     75%    max
# Usage           54.0   65.037037  58.317272  1.0  17.50  58.5   90.50  244.0
# Notifications   54.0  117.703704  97.017530  8.0  25.75  99.0  188.25  405.0
# Times opened    54.0   61.481481  43.836635  2.0  23.50  62.5   90.00  192.0

# %% [markdown]
# analyzing the screen time of the user. I will first look at the amount of usage of the apps:

# %%
sns.barplot(data,x='Date',y='Usage',hue='App')
plt.xticks(rotation=90);

# %% [markdown]
# look at the number of notifications from the apps:

# %%
sns.barplot(data, x='Date',y='Notifications', hue='App')
plt.xticks(rotation=90);

# %% [markdown]
# the number of times the apps opened:

# %%
sns.barplot(data, x='Date',y='Times opened', hue='App')
plt.xticks(rotation=90);

# %% [markdown]
# We generally use our smartphones when we get notified by any app. So let’s have a look at the relationship between the number of notifications and the amount of usage:

# %%
sns.scatterplot(data, x='Notifications', y='Usage')
# Out:
# <Axes: xlabel='Notifications', ylabel='Usage'>
